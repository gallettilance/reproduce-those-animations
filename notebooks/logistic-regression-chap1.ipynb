# %% [markdown]
# # Logistic Regression — Chapter 1 (The Sigmoid)
#
# Migrated to the **HITA** library. Run the setup cell once, then each export cell.
#
# Use `HITA_RENDER_PROFILE=draft` for fast previews, `hq` for final.
#
# **2** registered exports → `renders/`
#
# ```bash
# HITA_RENDER_PROFILE=draft python -m hita.export --chapter 1 --list
# ```

# %%
# --- Chapter 1 setup (HITA) ---

import os
from hita import load_chapter
from hita.stories.ch1 import CH1_EXPORT_SPECS as EXPORT_SPECS, export_clip

ctx = load_chapter(
    1,
    inherits=[],
    profile=os.environ.get("HITA_RENDER_PROFILE", "hq"),
)
globals().update(ctx.globals_dict)

n = len(EXPORT_SPECS)
native = getattr(ctx, "native", False)
print(
    f"Chapter {ctx.chapter} OK — profile={ctx.profile.name}, "
    f"exports={n}, native={native}, series={ctx.series.version}"
)

# %%
# ch1_74_sigmoid_pass_colormap_orbit.mp4
export_clip('ch1_74_sigmoid_pass_colormap_orbit.mp4')

# %%
# ch1_75_sigmoid_colormap_to_topdown.mp4
export_clip('ch1_75_sigmoid_colormap_to_topdown.mp4')
