# %% [markdown]
# # Logistic Regression — Chapter 2 (Parameters & the σ plane)
#
# Migrated to the **HITA** library. Run the setup cell once, then each export cell.
#
# Use `HITA_RENDER_PROFILE=draft` for fast previews, `hq` for final.
#
# **1** registered exports → `renders/`
#
# ```bash
# HITA_RENDER_PROFILE=draft python -m hita.export --chapter 2 --list
# ```

# %%
# --- Chapter 2 setup (HITA) ---

import os
from hita import load_chapter
from hita.stories.ch2 import CH2_EXPORT_SPECS as EXPORT_SPECS, export_clip

ctx = load_chapter(
    2,
    inherits=[1],
    profile=os.environ.get("HITA_RENDER_PROFILE", "hq"),
)
globals().update(ctx.globals_dict)

n = len(EXPORT_SPECS)
native = getattr(ctx, "native", False)
print(
    f"Chapter {ctx.chapter} OK — profile={ctx.profile.name}, "
    f"exports={n}, native={native}, series={ctx.series.version}"
)

# %%
# ch2_03_dataset_st_el_3d_sigmoid_morph.mp4
export_clip('ch2_03_dataset_st_el_3d_sigmoid_morph.mp4')
