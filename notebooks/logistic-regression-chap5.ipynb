# %% [markdown]
# # Logistic Regression — Chapter 5 (Can we trust the model?)
#
# Migrated to the **HITA** library. Run the setup cell once, then each export cell.
#
# Use `HITA_RENDER_PROFILE=draft` for fast previews, `hq` for final.
#
# **63** registered exports → `renders/`
#
# ```bash
# HITA_RENDER_PROFILE=draft python -m hita.export --chapter 5 --list
# ```

# %%
# --- Chapter 5 setup (HITA) ---

import os
import sys
from hita import load_chapter

# Drop stale modules/context so synced clips (54–58) are visible in this kernel.
for _mod in (
    "ch5_story",
    "ch5_prior_landscape",
    "ch5_core",
    "ch5_layout",
    "ch5_datasets",
    "hita.stories.ch5",
    "hita.stories.builders.ch5_47",
    "hita.stories.builders.ch5_landscape",
):
    sys.modules.pop(_mod, None)
from hita.export.context import clear_context_cache

clear_context_cache()

ctx = load_chapter(
    5,
    inherits=[3, 4],
    profile=os.environ.get("HITA_RENDER_PROFILE", "hq"),
)
globals().update(ctx.globals_dict)
# Bind after update so inherited chapter shims cannot overwrite this exporter.
from hita.stories.ch5 import CH5_EXPORT_SPECS as EXPORT_SPECS, export_clip

n = len(EXPORT_SPECS)
native = getattr(ctx, "native", False)
print(
    f"Chapter {ctx.chapter} OK — profile={ctx.profile.name}, "
    f"exports={n}, native={native}, series={ctx.series.version}"
)
if n < 68:
    raise RuntimeError(
        f"expected ≥68 Ch5 exports after sync, got {n}. "
        "Restart the kernel and re-run this setup cell."
    )
# Out:
# ch3:583: SyntaxWarning: invalid escape sequence '\s'
# ch3:587: SyntaxWarning: invalid escape sequence '\s'
# /Users/lance/Documents/BostonUniversity/PROJECTS/reproduce-those-animations/007-hita-logistic-regression/hita/legacy/notebooks/logistic-regression-chap3.ipynb:580: SyntaxWarning: invalid escape sequence '\s'
#   "    highlight_mistakes_flag=False,\n",
# /Users/lance/Documents/BostonUniversity/PROJECTS/reproduce-those-animations/007-hita-logistic-regression/hita/legacy/notebooks/logistic-regression-chap3.ipynb:584: SyntaxWarning: invalid escape sequence '\s'
#   "    if show_colormap and w_st is not None:\n",
# Chapter 3 setup OK — 20 clean, 26 with noise.
# Chapter 4 layout OK — handwriting: Patrick Hand
# Chapter 3 setup OK — 20 clean, 26 with noise.
# Chapter 5 OK — profile=hq, exports=58, native=False, series=0.2.0

# %%
# ch5_01_sequential_bars.mp4
export_clip('ch5_01_sequential_bars.mp4')

# %%
# ch5_02_bars_to_density.mp4
export_clip('ch5_02_bars_to_density.mp4')

# %%
# ch5_03_uniform_prior_sequential.mp4
export_clip('ch5_03_uniform_prior_sequential.mp4')

# %%
# ch5_04_sequential_ct.mp4
export_clip('ch5_04_sequential_ct.mp4')

# %%
# ch5_05_prior_sweep.mp4
export_clip('ch5_05_prior_sweep.mp4')

# %%
# ch5_06_prior_bowl.mp4
export_clip('ch5_06_prior_bowl.mp4')

# %%
# ch5_07_sequential.mp4
export_clip('ch5_07_sequential.mp4')

# %%
# ch5_08_decomposition.mp4
export_clip('ch5_08_decomposition.mp4')

# %%
# ch5_09_D1_squish.mp4
export_clip('ch5_09_D1_squish.mp4')

# %%
# ch5_10_D1_squish_uniform.mp4
export_clip('ch5_10_D1_squish_uniform.mp4')

# %%
# ch5_11_D1_ct.mp4
export_clip('ch5_11_D1_ct.mp4')

# %%
# ch5_12_D1_ct_uniform.mp4
export_clip('ch5_12_D1_ct_uniform.mp4')

# %%
# ch5_13_D2_squish.mp4
export_clip('ch5_13_D2_squish.mp4')

# %%
# ch5_14_D2_squish_uniform.mp4
export_clip('ch5_14_D2_squish_uniform.mp4')

# %%
# ch5_15_D2_ct.mp4
export_clip('ch5_15_D2_ct.mp4')

# %%
# ch5_16_D2_ct_uniform.mp4
export_clip('ch5_16_D2_ct_uniform.mp4')

# %%
# ch5_17_D3_squish.mp4
export_clip('ch5_17_D3_squish.mp4')

# %%
# ch5_18_D3_squish_uniform.mp4
export_clip('ch5_18_D3_squish_uniform.mp4')

# %%
# ch5_19_D3_ct.mp4
export_clip('ch5_19_D3_ct.mp4')

# %%
# ch5_20_D3_ct_uniform.mp4
export_clip('ch5_20_D3_ct_uniform.mp4')

# %%
# ch5_21_D4_squish.mp4
export_clip('ch5_21_D4_squish.mp4')

# %%
# ch5_22_D4_squish_uniform.mp4
export_clip('ch5_22_D4_squish_uniform.mp4')

# %%
# ch5_23_D4_ct.mp4
export_clip('ch5_23_D4_ct.mp4')

# %%
# ch5_24_D4_ct_uniform.mp4
export_clip('ch5_24_D4_ct_uniform.mp4')

# %%
# ch5_25_montage_4x4.mp4
export_clip('ch5_25_montage_4x4.mp4')

# %%
# ch5_26_duo_grid_2x2.mp4
export_clip('ch5_26_duo_grid_2x2.mp4')

# %%
# ch5_27_duo_grid_2x2_uniform.mp4
export_clip('ch5_27_duo_grid_2x2_uniform.mp4')

# %%
# ch5_28_ct_grid_2x2.mp4
export_clip('ch5_28_ct_grid_2x2.mp4')

# %%
# ch5_29_ct_grid_2x2_uniform.mp4
export_clip('ch5_29_ct_grid_2x2_uniform.mp4')
# Out:
# IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (3648, 2090) to (3648, 2096) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# wrote renders/ch5_29_ct_grid_2x2_uniform.mp4 (274 frames, text=False, ms=95)
# PosixPath('renders/ch5_29_ct_grid_2x2_uniform.mp4')

# %%
# ch5_30_credible_fill_D1.mp4
export_clip('ch5_30_credible_fill_D1.mp4')

# %%
# ch5_31_voxel_axis_D1.mp4
export_clip('ch5_31_voxel_axis_D1.mp4')

# %%
# ch5_32_credible_4x4.mp4
export_clip('ch5_32_credible_4x4.mp4')

# %%
# ch5_33_ct_D2.mp4
export_clip('ch5_33_ct_D2.mp4')

# %%
# ch5_34_voxel_D1.mp4
export_clip('ch5_34_voxel_D1.mp4')

# %%
# ch5_35_voxel_D1_uniform.mp4
export_clip('ch5_35_voxel_D1_uniform.mp4')

# %%
# ch5_36_voxel_D2.mp4
export_clip('ch5_36_voxel_D2.mp4')

# %%
# ch5_37_voxel_D2_uniform.mp4
export_clip('ch5_37_voxel_D2_uniform.mp4')

# %%
# ch5_38_voxel_D3.mp4
export_clip('ch5_38_voxel_D3.mp4')

# %%
# ch5_39_voxel_D3_uniform.mp4
export_clip('ch5_39_voxel_D3_uniform.mp4')

# %%
# ch5_40_voxel_D4.mp4
export_clip('ch5_40_voxel_D4.mp4')

# %%
# ch5_41_voxel_D4_uniform.mp4
export_clip('ch5_41_voxel_D4_uniform.mp4')

# %%
# ch5_42_dataset_2d_map.mp4
export_clip('ch5_42_dataset_2d_map.mp4')

# %%
# ch5_43_intro_to_01.mp4
export_clip('ch5_43_intro_to_01.mp4')

# %%
# ch5_44_tutorial_to_prior.mp4
export_clip('ch5_44_tutorial_to_prior.mp4')

# %%
# ch5_45_sequential_posterior_landscape.mp4
export_clip('ch5_45_sequential_posterior_landscape.mp4')

# %%
# ch5_46_uniform_prior_to_sequential.mp4
export_clip('ch5_46_uniform_prior_to_sequential.mp4')

# %%
# ch5_47_uniform_landscape_grid_2x2.mp4
export_clip('ch5_47_uniform_landscape_grid_2x2.mp4')

# %%
# ch5_48_uniform_landscape_grid_zoom.mp4
export_clip('ch5_48_uniform_landscape_grid_zoom.mp4')

# %%
# ch5_49_uniform_landscape_squish_ct.mp4
export_clip('ch5_49_uniform_landscape_squish_ct.mp4')

# %%
# ch5_50_uniform_landscape_grid_focus.mp4
export_clip('ch5_50_uniform_landscape_grid_focus.mp4')

# %%
# ch5_51_uniform_landscape_grid_d4_d2_zoom.mp4
export_clip('ch5_51_uniform_landscape_grid_d4_d2_zoom.mp4')

# %%
# ch5_52_posterior_map_perturb.mp4
export_clip('ch5_52_posterior_map_perturb.mp4')

# %%
# ch5_53_d4_origin_map_tutorial.mp4
export_clip('ch5_53_d4_origin_map_tutorial.mp4')

# %%
# ch5_54_grid_2d_zoom_shadow_orbit.mp4
export_clip('ch5_54_grid_2d_zoom_shadow_orbit.mp4')

# %%
# ch5_55_d1_loglik_overlay.mp4
export_clip('ch5_55_d1_loglik_overlay.mp4')
# Out:
# IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (3377, 1900) to (3392, 1904) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# wrote renders/ch5_55_d1_loglik_overlay.mp4 (370 frames, text=False, ms=90)
# PosixPath('renders/ch5_55_d1_loglik_overlay.mp4')

# %%
# ch5_56_grid_2d_zoom_shadow_orbit_topview.mp4
export_clip('ch5_56_grid_2d_zoom_shadow_orbit_topview.mp4')
# Out:
# /Users/lance/Documents/BostonUniversity/PROJECTS/reproduce-those-animations/007-hita-logistic-regression/hita/legacy/notebooks/logistic-regression-chap3.ipynb:529: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   "        if sigma_Z is None:\n",
# IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (3377, 1900) to (3392, 1904) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# wrote renders/ch5_56_grid_2d_zoom_shadow_orbit_topview.mp4 (320 frames, text=False, ms=90)
# PosixPath('renders/ch5_56_grid_2d_zoom_shadow_orbit_topview.mp4')

# %%
# ch5_57_grid_map_labeled_rotate90.mp4
export_clip('ch5_57_grid_map_labeled_rotate90.mp4')
# Out:
# /Users/lance/Documents/BostonUniversity/PROJECTS/reproduce-those-animations/007-hita-logistic-regression/hita/legacy/notebooks/logistic-regression-chap3.ipynb:529: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   "        if sigma_Z is None:\n",
# /Users/lance/Documents/BostonUniversity/PROJECTS/reproduce-those-animations/007-hita-logistic-regression/hita/legacy/notebooks/logistic-regression-chap3.ipynb:529: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   "        if sigma_Z is None:\n",
# ...

# %%
# ch5_58_belief_stem_surface.mp4
export_clip('ch5_58_belief_stem_surface.mp4')
# Out:
# IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (3377, 1900) to (3392, 1904) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# wrote renders/ch5_58_belief_stem_surface.mp4 (435 frames, text=False, ms=55)
# PosixPath('renders/ch5_58_belief_stem_surface.mp4')

# %%
# ch5_59_ct_to_voxel_grid_tour.mp4
export_clip('ch5_59_ct_to_voxel_grid_tour.mp4')

# %%
# ch5_60_tutorial_to_prior_stem_view.mp4 — ch5_44 with ch5_58 view_init
export_clip('ch5_60_tutorial_to_prior_stem_view.mp4')

# %%
# ch5_61_credible_interval_wander.mp4 — zoomed HPD probe + dark threshold (all datasets)
export_clip('ch5_61_credible_interval_wander.mp4')

# %%
# ch5_62_credible_thickness_wander.mp4 — 90° CCW then thickness-only HPD wander
export_clip('ch5_62_credible_thickness_wander.mp4')

# %%
# ch5_63_credible_axis_wander.mp4 — like 62; w_ST / w_EL / b ± one at a time
export_clip('ch5_63_credible_axis_wander.mp4')

# %%
# ch5_64_credible_thickness_wander_az0_45.mp4 — thickness wander at az 0° then 45°
export_clip('ch5_64_credible_thickness_wander_az0_45.mp4')

# %%
# ch5_65_credible_axis_wander_D1_views.mp4 — axis wander, D1 only
export_clip('ch5_65_credible_axis_wander_D1_views.mp4')

# %%
# ch5_66_credible_map_basis_quiver_orbit.mp4 — Hessian eigen-quivers + 360° orbit (D1)
export_clip('ch5_66_credible_map_basis_quiver_orbit.mp4')

# %%
# ch5_67_d3_belief_to_sigmoid_orbit.mp4 — D3 belief + 2D→3D sigmoid raise/orbit
export_clip('ch5_67_d3_belief_to_sigmoid_orbit.mp4')

# %%
# ch5_68_d1_fanout_credible.mp4 — D1→E2 triangle glide + batched adds + HPD + 360° orbit
export_clip('ch5_68_d1_fanout_credible.mp4')

# %%
# ch5_69_d2_noise_icon_emphasize.mp4 — zoomed D2: pulse pass-left then fail-right noise icons
export_clip('ch5_69_d2_noise_icon_emphasize.mp4')

# %%
# ch5_70_d1_best_line_howithink_d4_cuts.mp4 — D1 best-line celebrate → howithink → D4 rotating cuts → D1 parallels
export_clip('ch5_70_d1_best_line_howithink_d4_cuts.mp4')
