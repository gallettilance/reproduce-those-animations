# %% [markdown]
# # Logistic Regression — Chapter 6 (Frequentist sampling — how much does the line wiggle?)
#
# Migrated to the **HITA** library. Run the setup cell once, then each export cell.
#
# Use `HITA_RENDER_PROFILE=draft` for fast previews, `hq` for final.
#
# **34** registered exports → `renders/`
#
# ```bash
# HITA_RENDER_PROFILE=draft python -m hita.export --chapter 6 --list
# ```

# %%
# --- Chapter 6 setup (HITA) ---

import os
from hita import load_chapter

ctx = load_chapter(
    6,
    inherits=[3, 4, 5],
    profile=os.environ.get("HITA_RENDER_PROFILE", "hq"),
)
globals().update(ctx.globals_dict)
# Bind after update so inherited chapter shims cannot overwrite this exporter.
from hita.stories.ch6 import CH6_EXPORT_SPECS as EXPORT_SPECS, export_clip

n = len(EXPORT_SPECS)
native = getattr(ctx, "native", False)
print(
    f"Chapter {ctx.chapter} OK — profile={ctx.profile.name}, "
    f"exports={n}, native={native}, series={ctx.series.version}"
)

# %%
# ch6_01_observed_line.mp4
export_clip('ch6_01_observed_line.mp4')

# %%
# ch6_02_generative_coins.mp4
export_clip('ch6_02_generative_coins.mp4')

# %%
# ch6_03_resample_reel.mp4
export_clip('ch6_03_resample_reel.mp4')

# %%
# ch6_04_landing_histogram.mp4
export_clip('ch6_04_landing_histogram.mp4')

# %%
# ch6_05_looks_like_likelihood.mp4
export_clip('ch6_05_looks_like_likelihood.mp4')

# %%
# ch6_06_likelihood_bowl.mp4
export_clip('ch6_06_likelihood_bowl.mp4')

# %%
# ch6_07_lr_confidence.mp4
export_clip('ch6_07_lr_confidence.mp4')

# %%
# ch6_08_wald_vs_lr.mp4
export_clip('ch6_08_wald_vs_lr.mp4')

# %%
# ch6_09_separation.mp4
export_clip('ch6_09_separation.mp4')

# %%
# ch6_10_n_effect.mp4
export_clip('ch6_10_n_effect.mp4')

# %%
# ch6_11_d4_chaos.mp4
export_clip('ch6_11_d4_chaos.mp4')

# %%
# ch6_12_bayes_vs_freq.mp4
export_clip('ch6_12_bayes_vs_freq.mp4')

# %%
# ch6_13_class_gaussians.mp4
export_clip('ch6_13_class_gaussians.mp4')

# %%
# ch6_14_population_reel_n20.mp4
export_clip('ch6_14_population_reel_n20.mp4')

# %%
# ch6_15_population_reel_n8.mp4
export_clip('ch6_15_population_reel_n8.mp4')

# %%
# ch6_16_population_reel_n60.mp4
export_clip('ch6_16_population_reel_n60.mp4')

# %%
# ch6_17_population_reel_d1.mp4
export_clip('ch6_17_population_reel_d1.mp4')

# %%
# ch6_18_questions_intro.mp4
export_clip('ch6_18_questions_intro.mp4')

# %%
# ch6_19_classroom_walk.mp4
export_clip('ch6_19_classroom_walk.mp4')

# %%
# ch6_20_line_wiggle.mp4
export_clip('ch6_20_line_wiggle.mp4')

# %%
# ch6_21_record_parameters.mp4
export_clip('ch6_21_record_parameters.mp4')

# %%
# ch6_22_parameter_mean.mp4
export_clip('ch6_22_parameter_mean.mp4')

# %%
# ch6_23_variance_study.mp4
export_clip('ch6_23_variance_study.mp4')

# %%
# ch6_24_variance_units.mp4
export_clip('ch6_24_variance_units.mp4')

# %%
# ch6_25_three_variances.mp4
export_clip('ch6_25_three_variances.mp4')

# %%
# ch6_26_circle_vs_ellipse.mp4
export_clip('ch6_26_circle_vs_ellipse.mp4')

# %%
# ch6_27_covariance_matrix.mp4
export_clip('ch6_27_covariance_matrix.mp4')

# %%
# ch6_28_many_likelihoods.mp4
export_clip('ch6_28_many_likelihoods.mp4')

# %%
# ch6_29_expected_likelihood.mp4
export_clip('ch6_29_expected_likelihood.mp4')

# %%
# ch6_30_steep_vs_flat.mp4
export_clip('ch6_30_steep_vs_flat.mp4')

# %%
# ch6_31_one_classroom_problem.mp4
export_clip('ch6_31_one_classroom_problem.mp4')

# %%
# ch6_32_large_n_approx.mp4
export_clip('ch6_32_large_n_approx.mp4')

# %%
# ch6_33_hessian_to_cov.mp4
export_clip('ch6_33_hessian_to_cov.mp4')

# %%
# ch6_34_stability_outro.mp4
export_clip('ch6_34_stability_outro.mp4')
